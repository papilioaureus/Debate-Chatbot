# %% [markdown]
# #LOAD THE DATA

# %% [markdown]
# download from here:
#
# https://mega.nz/folder/ZdQGmK6b#-0hoBWc5fLYuxQuH25feXg

# %% [markdown]
# Import libraries

# %%
import pandas as pd
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from sqlalchemy import create_engine
from sqlalchemy import create_engine, MetaData, Table, Column, Integer, String, Float, Text

# %%
# Load the dataset
df = pd.read_csv('debate2019.csv')
df.head(5)
# Out:
#                                        Full-Document  \
# 0  The Trump Administration has been quietly fund...
# 1  The border between the United States and Mexic...
# 2  Today we face a planetary crisis. Environmenta...
# 3  “They talk to me about progress, about ‘achiev...
# 4  The Zapatista movement has garnered much atten...
#
#                                             Citation  \
# 0  Hunt 18 Edward Hunt writes about war and empir...
# 1  Monzo et al 17. Lilia D. Monzó, associate pro...
# 2  Helland and Lindgren 16 Leonardo E. Figueroa H...
# 3  Lystrup 15. Lauren; University of California, ...
# 4  Lystrup 15. Lauren, University of California, ...
#
#                                              Extract  \
# 0  The Trump Administration has been quietly fund...
# 1  The border between the United States and Mexic...
# 2  Today we face a planetary crisis. Environmenta...
# 3  They talk about progress, achievements,’ disea...
# 4  The Zapatista movement garnered attention in t...
#
#                                             Abstract  #CharsDocument  \
# 0  This file was produced by the following studen...            5041
# 1  Imperialism in Mexico is not just a one-off in...            9849
# 2  The will of dominion over Mexico is supplanted...           20340
# 3  Death is not a symptom or consequence of moder...            8774
# 4  Plan: The United States federal government sho...            6955
#
#    #CharsAbstract  #CharsExtract  #WordsDocument  #WordsAbstract  \
# 0             147           2106             788              25
# 1             431           4481            1559              71
# 2             698           8956            2660             109
# 3             425           4818            1272              63
# 4             161           3522            1023              23
#
#    #WordsExtract  AbsCompressionRatio  ExtCompressionRatio  \
# 0            326             0.031726             0.413706
# 1            693             0.045542             0.444516
# 2           1200             0.040977             0.451128
# 3            701             0.049528             0.551101
# 4            510             0.022483             0.498534
#
#                OriginalDebateFileName
# 0  Mexico Honduras  - Wake 2019.html5
# 1  Mexico Honduras  - Wake 2019.html5
# 2  Mexico Honduras  - Wake 2019.html5
# 3  Mexico Honduras  - Wake 2019.html5
# 4  Mexico Honduras  - Wake 2019.html5

# %% [markdown]
# #EXPLORE DATA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19057 entries, 0 to 19056
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Full-Document           19057 non-null  object
#  1   Citation                19057 non-null  object
#  2   Extract                 19057 non-null  object
#  3   Abstract                19057 non-null  object
#  4   #CharsDocument          19057 non-null  int64
#  5   #CharsAbstract          19057 non-null  int64
#  6   #CharsExtract           19057 non-null  int64
#  7   #WordsDocument          19057 non-null  int64
#  8   #WordsAbstract          19057 non-null  int64
#  9   #WordsExtract           19057 non-null  int64
#  10  AbsCompressionRatio     19057 non-null  float64
#  11  ExtCompressionRatio     19057 non-null  float64
#  12  OriginalDebateFileName  19057 non-null  object
# dtypes: float64(2), int64(6), object(5)
# memory usage: 1.9+ MB

# %% [markdown]
# statistical summary

# %%
df.describe()
# Out:
#        #CharsDocument  #CharsAbstract  #CharsExtract  #WordsDocument  \
# count    19057.000000    19057.000000   19057.000000    19057.000000
# mean      3924.182033      104.904340    1450.711445      615.153067
# std       4901.799047       91.408292    1483.013472      759.247243
# min        106.000000       14.000000      34.000000       20.000000
# 25%       1004.000000       57.000000     484.000000      156.000000
# 50%       2526.000000       83.000000    1028.000000      396.000000
# 75%       5215.000000      122.000000    1906.000000      819.000000
# max     227585.000000     3526.000000   23560.000000    32761.000000
#
#        #WordsAbstract  #WordsExtract  AbsCompressionRatio  ExtCompressionRatio
# count    19057.000000   19057.000000         19057.000000         19057.000000
# mean        16.189589     226.957181             0.072497             0.458851
# std         14.148261     231.108251             0.104213             0.197925
# min          4.000000      11.000000             0.000122             0.002656
# 25%          9.000000      76.000000             0.016471             0.310082
# 50%         13.000000     162.000000             0.034431             0.439490
# 75%         19.000000     299.000000             0.080808             0.590909
# max        530.000000    3693.000000             0.992188             0.998400

# %% [markdown]
# check missing values

# %%
df.isnull().sum()
# Out:
# Full-Document             0
# Citation                  0
# Extract                   0
# Abstract                  0
# #CharsDocument            0
# #CharsAbstract            0
# #CharsExtract             0
# #WordsDocument            0
# #WordsAbstract            0
# #WordsExtract             0
# AbsCompressionRatio       0
# ExtCompressionRatio       0
# OriginalDebateFileName    0
# dtype: int64

# %% [markdown]
# #CLEAN THE DATA

# %% [markdown]
# duplicates

# %%
print(df.columns.tolist())
# Out:
# ['Full-Document', 'Citation', 'Extract', 'Abstract', '#CharsDocument', '#CharsAbstract', '#CharsExtract', '#WordsDocument', '#WordsAbstract', '#WordsExtract', 'AbsCompressionRatio', 'ExtCompressionRatio', 'OriginalDebateFileName']

# %%
df_duplicates=df[df[['Full-Document', 'Citation', 'Extract', 'Abstract', '#CharsDocument', '#CharsAbstract', '#CharsExtract', '#WordsDocument', '#WordsAbstract', '#WordsExtract', 'AbsCompressionRatio', 'ExtCompressionRatio', 'OriginalDebateFileName']].duplicated() == True]
df_duplicates
# Out:
# Empty DataFrame
# Columns: [Full-Document, Citation, Extract, Abstract, #CharsDocument, #CharsAbstract, #CharsExtract, #WordsDocument, #WordsAbstract, #WordsExtract, AbsCompressionRatio, ExtCompressionRatio, OriginalDebateFileName]
# Index: []

# %% [markdown]
# remove unnecessary columns

# %% [markdown]
# #TEXT PREPROCESSING:
#
# Given our dataset, we will focus on the column 'Full-Document' for text processing.

# %% [markdown]
# Lowercasing

# %%
df['Full-Document'] = df['Full-Document'].str.lower()
df['Extract'] = df['Extract'].str.lower()

# %% [markdown]
# Tokenization

# %%
nltk.download('punkt')
df['Tokens'] = df['Full-Document'].apply(nltk.word_tokenize)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# Removing stop words

# %%
nltk.download('stopwords')
stop = set(stopwords.words('english'))
df['Filtered'] = df['Tokens'].apply(lambda x: [item for item in x if item not in stop])
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# Stemming/Lemmatisation

# %%
stemmer = PorterStemmer()
df['Stemmed'] = df['Filtered'].apply(lambda x: [stemmer.stem(y) for y in x])

# %% [markdown]
# removing special characters and numbers

# %%
df['Cleaned'] = df['Stemmed'].apply(lambda x: [item for item in x if item.isalpha()])

# %%
df.head()
# Out:
#                                        Full-Document  \
# 0  the trump administration has been quietly fund...
# 1  the border between the united states and mexic...
# 2  today we face a planetary crisis. environmenta...
# 3  “they talk to me about progress, about ‘achiev...
# 4  the zapatista movement has garnered much atten...
#
#                                             Citation  \
# 0  Hunt 18 Edward Hunt writes about war and empir...
# 1  Monzo et al 17. Lilia D. Monzó, associate pro...
# 2  Helland and Lindgren 16 Leonardo E. Figueroa H...
# 3  Lystrup 15. Lauren; University of California, ...
# 4  Lystrup 15. Lauren, University of California, ...
#
#                                              Extract  \
# 0  the trump administration has been quietly fund...
# 1  the border between the united states and mexic...
# 2  today we face a planetary crisis. environmenta...
# 3  they talk about progress, achievements,’ disea...
# 4  the zapatista movement garnered attention in t...
#
#                                             Abstract  #CharsDocument  \
# 0  This file was produced by the following studen...            5041
# 1  Imperialism in Mexico is not just a one-off in...            9849
# 2  The will of dominion over Mexico is supplanted...           20340
# 3  Death is not a symptom or consequence of moder...            8774
# 4  Plan: The United States federal government sho...            6955
#
#    #CharsAbstract  #CharsExtract  #WordsDocument  #WordsAbstract  \
# 0             147           2106             788              25
# 1             431           4481            1559              71
# 2             698           8956            2660             109
# 3             425           4818            1272              63
# 4             161           3522            1023              23
#
#    #WordsExtract  AbsCompressionRatio  ExtCompressionRatio  \
# 0            326             0.031726             0.413706
# 1            693             0.045542             0.444516
# 2           1200             0.040977             0.451128
# 3            701             0.049528             0.551101
# 4            510             0.022483             0.498534
#
#                OriginalDebateFileName  \
# 0  Mexico Honduras  - Wake 2019.html5
# 1  Mexico Honduras  - Wake 2019.html5
# 2  Mexico Honduras  - Wake 2019.html5
# 3  Mexico Honduras  - Wake 2019.html5
# 4  Mexico Honduras  - Wake 2019.html5
#
#                                               Tokens  \
# 0  [the, trump, administration, has, been, quietl...
# 1  [the, border, between, the, united, states, an...
# 2  [today, we, face, a, planetary, crisis, ., env...
# 3  [“, they, talk, to, me, about, progress, ,, ab...
# 4  [the, zapatista, movement, has, garnered, much...
#
#                                             Filtered  \
# 0  [trump, administration, quietly, funding, mexi...
# 1  [border, united, states, mexico, heavily, guar...
# 2  [today, face, planetary, crisis, ., environmen...
# 3  [“, talk, progress, ,, ‘, achievements, ,, ’, ...
# 4  [zapatista, movement, garnered, much, attentio...
#
#                                              Stemmed  \
# 0  [trump, administr, quietli, fund, mexican, gov...
# 1  [border, unit, state, mexico, heavili, guard, ...
# 2  [today, face, planetari, crisi, ., environment...
# 3  [“, talk, progress, ,, ‘, achiev, ,, ’, diseas...
# 4  [zapatista, movement, garner, much, attent, pa...
#
#                                              Cleaned
# 0  [trump, administr, quietli, fund, mexican, gov...
# 1  [border, unit, state, mexico, heavili, guard, ...
# 2  [today, face, planetari, crisi, environment, e...
# 3  [talk, progress, achiev, diseas, cure, improv,...
# 4  [zapatista, movement, garner, much, attent, pa...

# %%
df_cleaned=df

# %% [markdown]
# #SAVE PROCESSED DATA

# %% [markdown]
# Save to csv

# %%
df.to_csv('CleanDatasetChatbot.csv', index=False)

# %%
df = pd.read_csv('CleanDatasetChatbot.csv')

# %% [markdown]
# #BUILD DATABASE PIPELINE

# %%
#code to make the database split into 5 , make it smaller for storage
import pandas as pd

# Read the dataset
df = pd.read_csv('debate2019.csv')

# Split the dataset into five parts
chunk_size = len(df) // 5
chunk1 = df[:chunk_size]
chunk2 = df[chunk_size:2*chunk_size]
chunk3 = df[2*chunk_size:3*chunk_size]
chunk4 = df[3*chunk_size:4*chunk_size]
chunk5 = df[4*chunk_size:]

# Save each chunk to separate files
chunk1.to_csv('chunk1.csv', index=False)
chunk2.to_csv('chunk2.csv', index=False)
chunk3.to_csv('chunk3.csv', index=False)
chunk4.to_csv('chunk4.csv', index=False)
chunk5.to_csv('chunk5.csv', index=False)

# %% [markdown]
# terminal:

# %%
pip install sqlalchemy
# Out:
# Requirement already satisfied: sqlalchemy in /usr/local/lib/python3.10/dist-packages (2.0.27)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy) (4.9.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy) (3.0.3)

# %% [markdown]
# Since the 'Tokens', 'Filtered', 'Stemmed', and 'Cleaned' columns contain lists (which they do because of tokenization and other preprocessing steps we have done earlier), I will join these lists into strings before inserting the data into the SQL database.

# %%
columns_to_convert = ['Tokens', 'Filtered', 'Stemmed', 'Cleaned']

for column in columns_to_convert:
    df_cleaned[column] = df_cleaned[column].apply(lambda x: ' '.join(x) if isinstance(x, list) else x)

# %% [markdown]
# Create a Database and Tables with SQLAlchemy

# %%
# Define the engine to connect to the SQLite database.
engine = create_engine('sqlite:///chatbot_data.db')

metadata = MetaData()

# Define the schema for the 'documents' table.
documents_table = Table('documents', metadata,
                        Column('id', Integer, primary_key=True),
                        Column('FullDocument', Text),
                        Column('Citation', Text),
                        Column('Extract', Text),
                        Column('Abstract', Text),
                        Column('CharsDocument', Integer),
                        Column('CharsAbstract', Integer),
                        Column('CharsExtract', Integer),
                        Column('WordsDocument', Integer),
                        Column('WordsAbstract', Integer),
                        Column('WordsExtract', Integer),
                        Column('AbsCompressionRatio', Float),
                        Column('ExtCompressionRatio', Float),
                        Column('OriginalDebateFileName', String)
                        )

# Create the table in the specified database.
metadata.create_all(engine)

# %% [markdown]
# Insert data into the table

# %%
df.to_sql('debates', con=engine, if_exists='replace', index_label='id')
# Out:
# 19057

# %% [markdown]
# Database Schema

# %%
from IPython.display import IFrame

# Embedding the diagram within an IFrame, which will work in some cases depending on the Jupyter notebook's configuration
display(IFrame(src='https://dbdiagram.io/e/65db79cb5cd0412774c38b95/65db7e895cd0412774c3b8b5', width=560, height=315))
# Out:
#         <iframe
#             width="560"
#             height="315"
#             src="https://dbdiagram.io/e/65db79cb5cd0412774c38b95/65db7e895cd0412774c3b8b5"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# Insert Data to SQL

# %%
engine = create_engine('sqlite:///chatbot_data.db')
df.to_sql('chatbot_data', con=engine, if_exists='replace', index=False)
# Out:
# 19057

# %% [markdown]
# Have a look at the data

# %%
from sqlalchemy import create_engine, select, MetaData

metadata = MetaData()
metadata.reflect(bind=engine)

# Get the table object
table = metadata.tables['chatbot_data']

# Start a connection to the database
with engine.connect() as conn:
    # Prepare SELECT statement
    select_st = select(table)

    # Execute SELECT statement and fetch results
    result = conn.execute(select_st)

    # Fetch and print a few rows to check if it worked
    for row in result.fetchmany(size=5):
        print(row)
# Out:
# ('The Trump Administration has been quietly funding the Mexican government’s ongoing drug war, intensifying a conflict that claimed nearly 20,000 lives ... (4743 characters truncated) ... intensify the drug war, Trump is working to ensure that the people who suffer unfairly from it will never be able to find refuge inthe United States.', 'Hunt 18 Edward Hunt writes about war and empire. He has a PhD in American Studies from the College of William and Mary, “Trump’s Hidden Hand in Mexico’ Drug War,” April 7, 2018, https://progressive.org/dispatches/trumps-hidden-hand-in-mexicos-drug-war/)', 'The Trump Administration has been quietly funding the Mexican government’s ongoing drug war, intensifying a conflict that claimed nearly 20,000 lives ... (1808 characters truncated) ... intensify the drug war, Trump is working to ensure that the people who suffer unfairly from it will never be able to find refuge inthe United States.', 'This file was produced by the following students from the 2019 rKs lab in conjunction with and under the instruction of Dr. Shanara Reid Brinkley. ', 5041, 147, 2106, 788, 25, 326, 0.031725888324873, 0.4137055837563452, 'Mexico Honduras  - Wake 2019.html5')
# ('The border between the United States and Mexico is a heavily guarded panopticon of surveillance devices designed to control illegal Mexican immigrati ... (9551 characters truncated) ... isted the drug cartels when it has served the interests of the United States—defined in truth as the interests of the transnational capitalist class.', 'Monzo et al 17. Lilia D. Monzó, associate professor of education in the College of Educational Studies at Chapman University. Peter McLaren, disting ... (360 characters truncated) ... ns to Expendable Communities,” Cultural Studies, Critical Methodlogies, Volume 17, Issue 2, 201, p. 91-100. CW: mentions of sexual violence) ipartman', 'The border between the United States and Mexico is a heavily guarded panopticon of surveillance devices designed to control illegal Mexican immigrati ... (4183 characters truncated) ... and flexible regulations for U.S. corporations. the war on drugs also aids in keeping a citizenry in fear and more willing to acquiesce to authority.', 'Imperialism in Mexico is not just a one-off investment in the sapping of military aid but the lifeforce of drug war capitalism – the supply of Americ ... (133 characters truncated) ... rchy, capitalism, and other antagonisms to the Global South in order to squash dissent and defends its international position as world’s superpower. ', 9849, 431, 4481, 1559, 71, 693, 0.04554201411161, 0.4445157152020526, 'Mexico Honduras  - Wake 2019.html5')
# ('Today we face a planetary crisis. Environmental, energy, food, financial, and social reproduction crises are disrupting the world-system (Ahmed 2010; ... (20042 characters truncated) ...  decolonial, ecofeminist, posthumanist-ecological, and world-systems analysis we describe these infrastructures and how they feedback on each other:5', 'Helland and Lindgren 16 Leonardo E. Figueroa Helland, Assistant Professor of Political Science at Westminster College, M.A. Arizona State University, ... (130 characters truncated) ... es Around: From The Coloniality of Power to the Crisis of Civilization, Journal of World-Systems Research, 2016, Vol 22 Issue 2, p. 431-438) ipartman', 'Today we face a planetary crisis. Environmental, energy, food, financial, and social reproduction crises are disrupting the world-system This planeta ... (8658 characters truncated) ... rastructures must be critically and materially deconstructed to enable alternative worldviews lifeways organizational forms and practices to flourish', 'The will of dominion over Mexico is supplanted by a logic of exportation of Western civilization to the global south. The fungibility-machine of neol ... (400 characters truncated) ... logic of universality that valorizes the US as the locus of expertise. The only response to such is critical decolonization of American rule of law. ', 20340, 698, 8956, 2660, 109, 1200, 0.0409774436090225, 0.4511278195488721, 'Mexico Honduras  - Wake 2019.html5')
# ('“They talk to me about progress, about ‘achievements,’ diseases cured, improved standards of living. I am talking about societies drained of their es ... (8476 characters truncated) ... ble move toward decoloniality by demonstrating the incapacity for colonial thought and design to offer adequate blueprints to urgent global problems.', 'Lystrup 15. Lauren; University of California, Irvine, Doctor of Law (JD), 2015 – 2018. DePaul University Master\'s degree, Social and Cultural Founda ... (154 characters truncated) ... . "Decolonial Futures and the Law: Reflections on Mitigating Projects of Coloniality" (2015).\xa0http://via.library.depaul.edu/soe_etd/77~~) ipartman', 'They talk about progress, achievements,’ diseases cured, improved standards of living. I am talking about societies drained of their essence, culture ... (4520 characters truncated) ... e of envisaging move toward decoloniality by demonstrating the incapacity for colonial thought to offer adequate blueprints to urgent global problems', 'Death is not a symptom or consequence of modernity, but rather its intrinsic and foundational nature. Bringing decolonial political dissent to the ac ... (127 characters truncated) ... a power relation but makes normal and necessary war, imprisonment, and exploitation. Reasonable political desires of decolonality will never be met. ', 8774, 425, 4818, 1272, 63, 701, 0.0495283018867924, 0.5511006289308176, 'Mexico Honduras  - Wake 2019.html5')
# ('The Zapatista movement has garnered much attention in the past decade for their revolution against the North American Free Trade Agreement (NAFTA) an ... (6657 characters truncated) ... t and compartmentalization. The toxins of a colonial system need also be dealt with otherwise their seepage will only continue to bring about death. ', 'Lystrup 15. Lauren, University of California, Irvine, Doctor of Law (JD), 2015 – 2018. DePaul University Master\'s degree, Social and Cultural Founda ... (149 characters truncated) ...  2011. "Decolonial Futures and the Law: Reflections on Mitigating Projects of Coloniality" (2015). http://via.library.depaul.edu/soe_etd/77) ipartman', 'The Zapatista movement garnered attention in the past decade for their revolution against NAFTA and policies of globalization that sought to privatiz ... (3224 characters truncated) ... t and compartmentalization. The toxins of a colonial system need also be dealt with otherwise their seepage will only continue to bring about death. ', 'Plan: The United States federal government should substantially reduce its Foreign Military Arm Sales and Direct Commercial Sales to Mexico to decolonize Mexico.', 6955, 161, 3522, 1023, 23, 510, 0.0224828934506353, 0.4985337243401759, 'Mexico Honduras  - Wake 2019.html5')

# %% [markdown]
# #For prototype:
# ###Select the 2 subjects that appear the most and feed that data to the API in order to not overload the model or use too many tokens. We will also fine tune a model with this data.
#
# These will be the 2 subjects that appear the most in the document. We will look at the occurance of words (stop words not included), the number of times the same file name is detected, etc. to figure out which subbjects they are.

# %%
import pandas as pd
import nltk
from collections import Counter
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# Ensure you have the necessary NLTK data
nltk.download('punkt')
nltk.download('stopwords')

# Load the data
df_test = pd.read_csv('debate2019.csv')

# Concatenate all text data to one large string
all_text = ' '.join(df_test['Full-Document'].dropna())

# Tokenize the text into words
tokens = word_tokenize(all_text)

# Convert to lower case
tokens = [word.lower() for word in tokens]

# Remove punctuation and non-alphabetic tokens
words = [word for word in tokens if word.isalpha()]

# Remove common English stopwords
stop_words = set(stopwords.words('english'))
words = [word for word in words if not word in stop_words]

# Count the frequency of each word
word_counts = Counter(words)

# Print the two most common words
print(word_counts.most_common(20))
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [('states', 37122), ('would', 32075), ('china', 29972), ('united', 28305), ('military', 27700), ('war', 27171), ('nuclear', 25123), ('one', 24084), ('us', 23871), ('also', 23445), ('security', 21534), ('world', 21034), ('political', 18913), ('power', 18287), ('arms', 18011), ('weapons', 17603), ('new', 17422), ('could', 16987), ('trump', 16718), ('russia', 16696)]

# %%
df_test['OriginalDebateFileName'].nunique()
# Out:
# 364

# %%
df_test['OriginalDebateFileName'].unique()
# Out:
# array(['Mexico Honduras  - Wake 2019.html5',
#        'Ungovernability K  - Michigan7 2019 Starter Pack.html5',
#        'Revisionism Yes-No - MichiganClassic 2019 RW.html5',
#        'Israel Neg - DDI 2019 KS .html5',
#        'Saudi Arabia Aff Neg - Berkeley 2019 Starter.html5',
#        'Impact Turns Aff   Neg - Michigan7 2019 BFHMRS.html5',
#        'Saudi Neg - DDI 2019 KS .html5',
#        'Taiwan Aff - DDI 2019 KS .html5',
#        'Politics Agenda  DA - Scholars - Gonzaga 2019.html5',
#        'Topicality  - Michigan7 2019 Starter Pack.html5',
#        'Liberal Militarism K - DDI 2019 Generic.html5',
#        'End Use CP - Berkeley 2019 Starter.html5',
#        'Saudi Threaten CP - Samford 2019.html5',
#        'Security K Starter Set - Gonzaga 2019.html5',
#        'Framework - Michigan7 2019 HKMM.html5',
#        'ROC Aff and Neg Preinstitute Set - Wake 2019.html5',
#        'Iron Triangle Neg - DDI 2019 LO.html5',
#        'Deterrence DA Updates - Michigan7 2019 CCPW.html5',
#        'Oil Da supplement - Scholars - Gonzaga 2019.html5',
#        'Decolonization 1ac - Wake 2019.html5',
#        'Taiwan Arms Sales Negative - Emory 2019.html5',
#        'Philippines Aff   Neg - Michigan7 2019 HKMM.html5',
#        'Condition CP - Scholars - Gonzaga 2019.html5',
#        'Bataille K - Michigan7 2019 K Lab.html5',
#        'Saudi Arabia Aff - Michigan7 2019 HJPP.html5',
#        'Reps Defenses - Michigan7 2019 CCPW.html5',
#        'Circumvention - HSS 2019.html5',
#        'T - Reduce Arms Sales - Michigan7 2019 FFPSV.html5',
#        'Consult Congress CP - Michigan7 2019 FFPSV.html5',
#        'ROC 2ac K answers Preinstitute Set - Wake 2019 (1).html5',
#        'Sex Workers Policy 1ac - Wake 2019.html5',
#        'Black FW - Wake 2019.html5',
#        'Greasetrap masterfile - Wake 2019.html5',
#        'Defense Industrial Base DA - Emory 2019.html5',
#        'FMS Surcharge CP - Michigan7 2019 BFHR.html5',
#        'Saudi Aff Neg Supplement - Georgetown 2019.html5',
#        'Topicality - SDI 2019.html5', 'White FW - Wake 2019.html5',
#        'Security Kritik - SDI 2019.html5',
#        'Democracy Good   Bad - Michigan7 2019 CCPW.html5',
#        'Defense Industrial Base DA  - 4 Week Lab - Gonzaga 2019.html5',
#        'Race War v2 - Wake 2019.html5',
#        'Ligotti masterfile - Wake 2019.html5',
#        'Dollar Hege DA - Berkeley 2019.html5',
#        'Black Palestinian Aff  - Wake 2019 (1).html5',
#        'Bataille Aff master file - Wake 2019.html5',
#        'Debt Ceiling Politics DA - DDI 2019 KM.html5',
#        'Egypt Aff  - Michigan7 2019 CCPW.html5',
#        'USMCA Politics DA - Michigan7 2019 Starter Pack.html5',
#        'CAT AFF - MichiganClassic 2019 MPP.html5',
#        'Mexico Small Arms Aff - Michigan7 2019 FFPSV.html5',
#        'Defense Industrial Base DA - Impact Supplement - Georgetown 2019.html5',
#        'Saudi Arabia Aff 3 - Michigan7 2019 BFHR.html5',
#        'China Fill In DA - Georgetown 2019.html5',
#        'Taiwan Neg - DDI 2019 KM.html5',
#        'Settler Colonialism K  - Michigan7 2019 K Lab.html5',
#        'Human Rights Aff   Neg - Michigan7 2019 Starter Pack.html5',
#        'Saudi Arabia Aff  - MichiganClassic 2019 FH.html5',
#        'Antiblackness K - MichiganClassic 2019 K Lab.html5',
#        'Japan BMD Neg - DDI 2019 KS .html5',
#        'Taiwan Aff  - Michigan7 2019 BFHR.html5',
#        'Israel Set Col aff and neg - Scholars - Gonzaga 2019.html5',
#        'Saudi Alliance DA - Berkeley 2019 Starter.html5',
#        'Impact Core  - Michigan7 2019 FFPSV.html5',
#        'Israel BDS Neg Preinstitute Set - Wake 2019.html5',
#        'Antiblackness Kritik - SDI 2019.html5',
#        'Torture Trade Aff - Michigan7 2019 CCPW.html5',
#        'Human Rights Aff 2.0 - Michigan7 2019 HJPP.html5',
#        'Mexico Small Arms Supplement Aff   Neg - Michigan7 2019 HKMM.html5',
#        'Ukraine Neg - Michigan7 2019 HKMM.html5',
#        'Afropessimism Aff - Wake 2019.html5',
#        'Japan BMD Aff - DDI 2019 KM.html5',
#        'Executive Power DA and CP - DDI 2019 Generic.html5',
#        '2020 Election DA - HSS 2019.html5',
#        'Taiwan Arms Sales Case Neg - 4 Week Lab - Gonzaga 2019.html5',
#        'Gender Negative - SDI 2019.html5',
#        'Curtiss Wright Aff - DDI 2019 KM.html5',
#        'Human Rights Neg 2-0 - Michigan7 2019 HJPP.html5',
#        'Queer IR K - Berkeley 2019.html5',
#        'Drones Neg - DDI 2019 KS .html5', 'MTCR Neg - DDI 2019 LO.html5',
#        'Aff K Answers  - MichiganClassic 2019 BFHMRS.html5',
#        'Cap and Semiocap K - MichiganClassic 2019 K Lab.html5',
#        'Taiwan Arms Sales Affirmative - Emory 2019.html5',
#        'Deterrence DA v K Updates  - Michigan7 2019 HKMM.html5',
#        'Biden Mechanism Affirmative - SDI 2019.html5',
#        'Set Col - Wake 2019.html5',
#        'Egypt Neg  - Michigan7 2019 CCPW.html5',
#        'Mexico Aff and Neg Wave 1 - Sophomores - Gonzaga 2019.html5',
#        'Taiwan Aff - Michigan7 2019 Starter Pack.html5',
#        'Taiwan Genealogy - 4 Week Lab - Gonzaga 2019.html5',
#        'Mexico Neg - DDI 2019 KS .html5',
#        'Ukraine Aff - Michigan7 2019 BFHR.html5',
#        'T - Subsets - Michigan7 2019 BFHR.html5',
#        'Proliferation Good Bad - SDI 2019.html5',
#        'Topicality Arms Aff Supplement - HSS 2019.html5',
#        'Security K supplement - 4 Week Lab - Gonzaga 2019.html5',
#        'Game of Thrones DA 2 - Michigan7 2019 HJPP.html5',
#        'Saudi Relations DA - Georgetown 2019.html5',
#        'De-Development - SDI 2019.html5',
#        'Qatar Neg - Michigan7 2019 BFHR.html5',
#        'US Saudi Arabia Leadership - Scholars - Gonzaga 2019.html5',
#        'Israel Zionism Aff Neg - Berkeley 2019.html5',
#        'Militarism Neg - DDI 2019 KS .html5',
#        'Climate Financing CP - Sophomores - Gonzaga 2019.html5',
#        'Saudi Arabia Aff and ME Heg Bad - MichiganClassic 2019 RW.html5',
#        'Tear Gas Aff and Neg - Sophomores - Gonzaga 2019.html5',
#        'Weaponitis K - Sophomores - Gonzaga 2019.html5',
#        'Psychoanalysis Bad - Michigan7 2019 CCPW.html5',
#        'Credibility Bad DA - SDI 2019.html5',
#        'Saudi Arabia internal Politics - Scholars - Gonzaga 2019.html5',
#        'USMCA Politics DA 2 - Michigan7 2019 BFHR.html5',
#        'Militarism Neg - DDI 2019 LO.html5',
#        'Consult Japan CP - Michigan7 2019 CCPW.html5',
#        'Israel Neg - DDI 2019 KM.html5',
#        'F-35 Thumper Aff   Neg - Michigan7 2019 BFHMRS.html5',
#        'Framework Supplement - HSS 2019.html5',
#        'K Aff Supplement - Michigan7 2019 FFPSV.html5',
#        'Militarism K Supplement - Berkeley 2019.html5',
#        'Saudi Condition CP 2 - Georgetown 2019.html5',
#        'Debt Ceiling Politics DA - Berkeley 2019.html5',
#        'Defense Industrial Base DA - Michigan7 2019 Starter Pack.html5',
#        'Small Arms Aff Neg - Berkeley 2019.html5',
#        'Israel Aff Supplement - MichiganClassic 2019 HJO.html5',
#        'Militarism Aff-Neg - Michigan7 2019 K Lab.html5',
#        'Cap vs K Affs - Michigan7 2019 BFHR.html5',
#        'Poland Aff   Neg - Michigan7 2019.html5',
#        'Saudi Oversight Aff and Neg - Samford 2019.html5',
#        'Spanos K - Wake 2019.html5',
#        'Circumvention Core - Berkeley 2019.html5',
#        'Russia DA 2 - Michigan7 2019 BFHR.html5',
#        'ROC aff supplement - Wake 2019.html5',
#        'Politics DA - SDI 2019.html5',
#        'T Substantial - Samford 2019.html5',
#        'Settler Colonialism K - Michigan7 2019 CPWW.html5',
#        'Oil DA  - Michigan7 2019 HKMM.html5',
#        'International Law Bad - Michigan7 2019 BFHR.html5',
#        'Israel Uniqueness CP - Berkeley 2019.html5',
#        'Presidential Powers DA - Samford 2019.html5',
#        'Saudi Coalition Affirmative - HSS 2019.html5',
#        'Curtiss Wright Neg - DDI 2019 KS .html5',
#        'Aff T -Subsets - Michigan7 2019.html5',
#        'Small Arms Neg - Michigan7 2019 BFHR.html5',
#        'US Saudi Relations DA Starter Set - Gonzaga 2019.html5',
#        'Deleuze Aff   Neg - Michigan7 2019 K Lab.html5',
#        'Saudi Aff Neg Supplement 3 - Georgetown 2019.html5',
#        'Economy and Defense Industry DA - SDI 2019.html5',
#        'Philippines Aff   Neg - Michigan7 2019 FFPSV.html5',
#        'Security supplement- Scholars - Gonzaga 2019.html5',
#        'Biden Mechanism Negative - SDI 2019.html5',
#        'Iron Triangle Neg - DDI 2019 KM.html5',
#        'Ukraine DA - Scholars - Gonzaga 2019.html5',
#        'Topicality  - DDI 2019 Generic.html5',
#        'Israel Aff   Neg - Michigan7 2019 Starter Pack.html5',
#        'Arms Control K  - Michigan7 2019 Starter Pack.html5',
#        'Russia DA - SDI 2019.html5',
#        'Saudi Arabia Updates Aff   Neg - Michigan7 2019 HJPP.html5',
#        'Ukraine Aff 2 - Michigan7 2019 BFHR.html5',
#        'USMCA DA - Samford 2019.html5',
#        '2020 Elections DA - Michigan7 2019 CCPW.html5',
#        'Israel Militant Anti-Militarism Aff   Neg - Michigan7 2019 K Lab.html5',
#        'Psychoanalysis K - Wake 2019.html5',
#        "Advantage CP's - Michigan7 2019 BFHR.html5",
#        'Delooze - Wake 2019.html5',
#        'Mexico Small Arms Neg - Michigan7 2019 FFPSV.html5',
#        'Settler Colonialism K - Berkeley 2019.html5',
#        'Weaponitis Kritik - Georgetown 2019.html5',
#        'Taiwan Genealogy Aff- 4 Week Lab - Gonzaga 2019.html5',
#        'Militarism Aff - DDI 2019 LO.html5',
#        'Ukraine Affirmative - SDI 2019.html5',
#        'Orientalism K - Berkeley 2019.html5',
#        'Taiwan Affirmative - SDI 2019.html5',
#        'China War Good  - Michigan7 2019 BFHR.html5',
#        'Consult NATO - Michigan7 2019 CCPW.html5',
#        'Saudi Relations DA - Samford 2019.html5',
#        'Advantage CPs - Berkeley 2019.html5',
#        'Arms Sales K - Scholars - Gonzaga 2019.html5',
#        'Defense Industry DA - Berkeley 2019 Starter.html5',
#        'T - Reduce - Michigan7 2019 BFHR.html5',
#        'Allies DA - Michigan7 2019 BFHR.html5',
#        'Taiwan Arms Sales affirmatives Neg - 4 Week Lab - Gonzaga 2019.html5',
#        'Congressional Oversight CP Answers - HSS 2019.html5',
#        'Saudi Arabia Aff   Neg - Michigan7 2019 BFHR.html5',
#        'Israel Conditions CP - Berkeley 2019.html5',
#        'Militarism K - Berkeley 2019.html5',
#        'Proliferation - Michigan7 2019 BFHR.html5',
#        'Consult Japan CP - Berkeley 2019.html5',
#        'China DA - Michigan7 2019 Starter Pack.html5',
#        'Saudi Neg - DDI 2019 LO.html5',
#        'Black Cybernetics Aff - Michigan7 2019 K Lab.html5',
#        'Taiwan Neg - DDI 2019 LO.html5',
#        'AT Baudrillard - Wake 2019.html5',
#        'Taiwan Neg - Michigan7 2019 BFHR.html5',
#        'Quashie masterfile - Wake 2019.html5',
#        'Taiwan Arms Sales spillover - 4 Week Lab - Gonzaga 2019.html5',
#        'T Definitions - Sophomores - Gonzaga 2019.html5',
#        'ANTS Aff - Michigan7 2019 HKMM.html5',
#        'Environment Impact Core - Michigan7 2019 HJPP.html5',
#        '2020 DA - Berkeley 2019.html5',
#        'Advantage CP Starter Set - Gonzaga 2019.html5',
#        'Security K  - Michigan7 2019 BFHR.html5',
#        'Japan BMD Neg - DDI 2019 KM.html5',
#        'Executive Order CP - Samford 2019.html5',
#        'USMCA Politics DA - SDI 2019.html5',
#        'Taiwan Aff Neg - Berkeley 2019.html5',
#        'Taiwan Arms Sales aff and Neg supplement - 4 Week Lab - Gonzaga 2019.html5',
#        'Saudi Aff and Neg Starter Set- GDI  - Gonzaga 2019.html5',
#        'Taiwan Negative - SDI 2019.html5',
#        'Ukraine Affirmative - HSS 2019.html5',
#        'Imperialism - Terror DA K  - Michigan7 2019 K Lab.html5',
#        'Philippines Aff Neg - Berkeley 2019.html5',
#        'EUM CP - Michigan7 2019 BFHR.html5',
#        'Saudi Arabia Oil DA - Scholars - Gonzaga 2019.html5',
#        'Saudi Arabia Neg - DDI 2019 KM.html5',
#        'Curtiss Wright Neg - DDI 2019 LO.html5',
#        'Reform Arms Sales CP - Emory 2019.html5',
#        'F-16 Neg - Michigan7 2019 HJPP.html5',
#        'Saudi Coalition Negative - HSS 2019.html5',
#        'Saudi Aff Neg Supplement 2 - Georgetown 2019.html5',
#        'Assurances DA  - 4 Week Lab - Gonzaga 2019.html5',
#        'Liberal Pacification Kritik - HSS 2019.html5',
#        'Israel 2 Aff   Neg - Michigan7 2019 HJPP.html5',
#        'Russia DA - Michigan7 2019 Starter Pack.html5',
#        'Congressional Oversight Neg - DDI 2019 KM.html5',
#        'Israel DA - DDI 2019 KM.html5',
#        'Congressional Oversight Neg - DDI 2019 LO.html5',
#        'Saudi Arabia 3 Neg - Michigan7 2019 BFHR.html5',
#        'Cap K Preinstitute Set - Wake 2019.html5',
#        'Ukraine Neg - Michigan7 2019 BFHR.html5',
#        'CAT Neg  - MichiganClassic 2019 MPP.html5',
#        'Alliance Impact Core - Michigan7 2019 HKMM.html5',
#        'Fem IR K - Michigan7 2019 HKMM.html5',
#        'Qatar Aff  - Michigan7 2019 BFHR.html5',
#        'Performance Args - Wake 2019.html5',
#        'Russia Fill In DA - Gonzaga 2019.html5',
#        'Liberalism Good - Michigan7 2019 CCPW.html5',
#        'Russia Fill In DA - Georgetown 2019.html5',
#        'Curtiss Wright Neg - DDI 2019 KM.html5',
#        'Gender Affirmative - SDI 2019.html5',
#        'Saudi Arabia Neg  - Michigan7 2019 HJPP.html5',
#        '1033 DA - Scholars - Gonzaga 2019.html5',
#        'Wakanda CP - Michigan7 2019 K Lab.html5',
#        'Nonviolence K - MichiganClassic 2019 FH.html5',
#        'Asia Prolif DA Supplement - Berkeley 2019.html5',
#        'Taiwan Neg - Michigan7 2019 Starter Pack.html5',
#        'Baudrillard Aff   Neg - Michigan7 2019 K Lab.html5',
#        'Mexico Aff and Neg supplement - Sophomores - Gonzaga 2019.html5',
#        'Tactical Carnival Aff Neg - Berkeley 2019.html5',
#        'R-Spec File - Wake 2019.html5',
#        'Neoliberalism K - MichiganClassic 2019 EGW.html5',
#        'Saudi Aff Neg - Georgetown 2019.html5',
#        'Taiwan Negative Supplement - HSS 2019.html5',
#        'Heg Bad Impact Core - Michigan7 2019 FFPSV.html5',
#        'Topicality Substantially Reduce (Ceiling) - HSS 2019.html5',
#        'Defense Industrial Base DA - Georgetown 2019.html5',
#        'Ungovernability K - Michigan7 2019 HKMM.html5',
#        'Topicality Supplement - Michigan7 2019 FFPSV.html5',
#        'Executive Power DA - Georgetown 2019.html5',
#        'Israel FMF Aff Neg - Berkeley 2019.html5',
#        'Israel human rights aff and neg - Scholars - Gonzaga 2019.html5',
#        'Baudrillard - Wake 2019.html5', 'Academy K - Wake 2019.html5',
#        'Climate Offsets CP - Michigan7 2019 BFHR.html5',
#        'Drones Supplement Aff   Neg - MichiganClassic 2019 HJO.html5',
#        'Cede the Political DA - Michigan7 2019 CCPW.html5',
#        'Appeasement DA  - Michigan7 2019 FFPSV.html5',
#        'Africom Aff - Wake 2019.html5',
#        'Middle East Allies DA  - DDI 2019 Generic.html5',
#        'IR Core  - Michigan7 2019 HJPP.html5',
#        'Anarch-AntiMilitarism Aff - Michigan7 2019 HKMM.html5',
#        'Saudi Arabia Air Force DA - Scholars - Gonzaga 2019.html5',
#        'Nommo 1ac  neg 2.0 - Wake 2019.html5',
#        'cards for rks tournament - Wake 2019.html5',
#        'anti blackness master file - Wake 2019.html5',
#        'Drones Neg - DDI 2019 KM.html5',
#        'Leadership DA - 4 Week Lab - Gonzaga 2019.html5',
#        'Conditions Core  - Michigan7 2019 HJPP.html5',
#        'Ukraine Negative - SDI 2019.html5',
#        'Taiwan Aff Supplement - HSS 2019.html5',
#        'Topicality - Emory 2019.html5',
#        'Saudi Courts Aff  - Michigan7 2019 BFHR.html5',
#        'Spark - Michigan7 2019 BFHR.html5',
#        'Saudi Courts Neg - Michigan7 2019 BFHR.html5',
#        'Politics Updates - SDI 2019.html5',
#        'Mexico Neg - DDI 2019 KM.html5',
#        'Liberal Order Bad   Good - Michigan7 2019 CCPW.html5',
#        'Security K  - 4 Week Lab - Gonzaga 2019.html5',
#        'All American Aff - Wake 2019.html5',
#        'Nietzsche K - Michigan7 2019 BFHR.html5',
#        'China DA Supplement - MichiganClassic 2019 BAZ.html5',
#        'Oil DA - DDI 2019 KS .html5', 'China DA - Berkeley 2019.html5',
#        'Tactical Retaliation Updates - Berkeley 2019.html5',
#        'Nigeria Aff  - MichiganClassic 2019 BAZ.html5',
#        'Weapons Focus K - DDI 2019 Generic.html5',
#        'Set Col 2.0 - Wake 2019.html5',
#        'Defense Industrial Base DA - Samford 2019.html5',
#        'Ukraine Negative - HSS 2019.html5',
#        'Forensic Ecology Aff and Neg - Wake 2019.html5',
#        'Congress Advantage - Georgetown 2019.html5',
#        'Orientalism Masterfile - Wake 2019.html5',
#        'Legislative Veto Neg - DDI 2019 LO.html5',
#        'Aegis Neg - DDI 2019 LO.html5',
#        'Prolif reps K Starter Set - Gonzaga 2019.html5',
#        'North Korean War  - Michigan7 2019 HJPP.html5',
#        'Cap K - Wake 2019.html5', 'Drones Aff Neg - Berkeley 2019.html5',
#        'Mexico Neg - DDI 2019 LO.html5',
#        'Politics 2020  DA - Scholars - Gonzaga 2019.html5',
#        'K Aff Neg - Michigan7 2019 BFHR.html5',
#        'Ukraine Aff - Michigan7 2019 HKMM.html5',
#        'Capitalism K - Berkeley 2019.html5',
#        'Israel Affirmative - SDI 2019.html5',
#        'Offsets PIC - DDI 2019 KM.html5', 'Security K - Wake 2019.html5',
#        'Heg DA - Michigan7 2019 FFPSV.html5',
#        'Alliance DA Supplement - Berkeley 2019.html5',
#        'Fem IR Saudi Aff - DDI 2019 KS .html5',
#        'Stick UP  - Wake 2019.html5',
#        'Defense Industrial Base and Fill-In DA - DDI 2019 Generic.html5',
#        'Sabotage Aff  - Wake 2019.html5',
#        'Torture Trade Neg - Michigan7 2019 CCPW.html5',
#        'Security Kritik - Emory 2019.html5',
#        'Political Theology - Michigan7 2019 K Lab.html5',
#        'Asia Allied Assurance DA - DDI 2019 Generic.html5',
#        'Leverage CP - Asia - DDI 2019 Generic.html5',
#        'Fabulation Case neg - Wake 2019.html5',
#        'Taiwan Aff Update - Michigan7 2019 BFHR.html5',
#        'T - Substantial - Michigan7 2019 BFHR.html5',
#        'Circumvention - SDI 2019.html5',
#        'Farm Bill Counterfactual - Wake 2019.html5',
#        'Settler Colonialism K - Michigan7 2019 BFHR.html5',
#        'Nigeria Neg - MichiganClassic 2019 BAZ.html5',
#        'Israel BDS Aff Preinstitute Set - Wake 2019.html5',
#        'Debt Ceiling Politics DA - SDI 2019.html5',
#        'Framework - Scholars - Gonzaga 2019.html5',
#        'Saudi Conditions CP - Georgetown 2019.html5',
#        'Democracy Good Bad - Georgetown 2019.html5',
#        'Militarism K Supplement - MichiganClassic 2019 HJO.html5',
#        'Saudi Arabia Aff   Neg - Michigan7 2019 Starter Pack.html5',
#        'Framing - SDI 2019.html5',
#        'Arms Sales Updates - Michigan7 2019 FFPSV.html5',
#        'Oil DA - Berkeley 2019 Starter.html5',
#        'Nommo 1ac aff neg cards - Wake 2019.html5',
#        'ROC and China and Assurances supplement  - 4 Week Lab - Gonzaga 2019.html5',
#        'Hegemony Core - SDI 2019.html5',
#        'Saudi Arabia Aff - DDI 2019 LO.html5',
#        'Taiwan Neg - DDI 2019 KS .html5',
#        'Leverage CP - Middle East  - DDI 2019 Generic.html5',
#        'Realism Good - Michigan7 2019 CCPW.html5',
#        'Saudi Gender Aff - Michigan7 2019 CCPW.html5',
#        'Ukraine aff and neg - Wake 2019.html5',
#        'Drones Aff   Neg - Michigan7 2019 FFPSV.html5',
#        'Taiwan F16 Neg - Michigan7 2019 BFHR.html5',
#        'Tear Gas Supplement - Sophomores - Gonzaga 2019.html5',
#        'Israel Negative - SDI 2019.html5',
#        'Topicality - Berkeley 2019 Starter.html5',
#        'Ukraine Updates Aff   Neg - Michigan7 2019 CCPW.html5',
#        'Congressional Oversight Aff - DDI 2019 LO.html5',
#        'Gender Kritik - SDI 2019.html5',
#        'Israel Neg Supplement  - MichiganClassic 2019 HJO.html5',
#        'Assurances DA - Berkeley 2019.html5',
#        'Heg Good Impact Core - Michigan7 2019 FFPSV.html5',
#        'Russia DA - Berkeley 2019.html5'], dtype=object)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

df_keydate_counts = df_test['OriginalDebateFileName'].value_counts().sort_index().reset_index()
df_keydate_counts.columns = ['OriginalDebateFileName', 'count']

plt.figure(figsize=(10, 100))
sns.barplot(x='count', y='OriginalDebateFileName', data=df_keydate_counts, orient='h')
plt.title("Number of occurrences of each file name")
plt.xlabel("Number of occurrences")
plt.ylabel("filename")
plt.figure(figsize=(1000, 1000))

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Plot a histogram and kernel density estimate (KDE) of filename
plt.figure(figsize=(80, 10))

sns.histplot(df_test['OriginalDebateFileName'].dropna(), kde=True)
plt.title('File name Distribution')
plt.xlabel('filename')
plt.ylabel('Frequency')

plt.show()

# %%
file_name_balance = df_test['OriginalDebateFileName'].value_counts()
print("\nFile Name balance:\n", file_name_balance)
# Out:
# File Name balance:
#  Ukraine Updates Aff   Neg - Michigan7 2019 CCPW.html5                         268
# Impact Turns Aff   Neg - Michigan7 2019 BFHMRS.html5                          264
# Saudi Courts Neg - Michigan7 2019 BFHR.html5                                  214
# Allies DA - Michigan7 2019 BFHR.html5                                         195
# Nigeria Aff  - MichiganClassic 2019 BAZ.html5                                 191
#                                                                              ...
# Congressional Oversight Neg - DDI 2019 KM.html5                                 1
# Advantage CP Starter Set - Gonzaga 2019.html5                                   1
# Taiwan Arms Sales spillover - 4 Week Lab - Gonzaga 2019.html5                   1
# ROC and China and Assurances supplement  - 4 Week Lab - Gonzaga 2019.html5      1
# Politics Agenda  DA - Scholars - Gonzaga 2019.html5                             1
# Name: OriginalDebateFileName, Length: 364, dtype: int64

# %%
import pandas as pd
import json
#to csv

df_test = pd.read_csv('debate2019.csv')

# Filter the dataframe to keep only the rows with the specified file name
filtered_df = df_test[df_test['OriginalDebateFileName'] == 'Ukraine Updates Aff   Neg - Michigan7 2019 CCPW.html5']

# Save the filtered dataframe to a new csv file
filtered_csv_path = 'Ukraine_text.csv'
filtered_df.to_csv(filtered_csv_path, index=False)

filtered_csv_path
# Out:
# 'Ukraine_text.csv'

# %%
import pandas as pd
import json
#to txt

df_test = pd.read_csv('debate2019.csv')

# Filter the dataframe to keep only the rows with the specified file name
filtered_df = df_test[df_test['OriginalDebateFileName'] == 'Ukraine Updates Aff   Neg - Michigan7 2019 CCPW.html5']

# Save the filtered dataframe to a new csv file
filtered_csv_path = 'filtered_database.csv'
filtered_df.to_csv(filtered_csv_path, index=False)


# Concatenate all the values in the 'Full-Document' column into a single text
Ukraine_text = '\n'.join(filtered_df['Full-Document'].astype(str))

# Save the concatenated text to a .txt file
text_file_path = 'Ukraine_text.txt'
with open(text_file_path, 'w') as file:
    file.write(Ukraine_text)

text_file_path
# Out:
# 'Ukraine_text.txt'

# %% [markdown]
# This is what we get in terms of which subejcts appear most times, and specifically how many times:
#
#
# First:
# - Ukraine Updates Aff   Neg - Michigan7 2019 CCPW.html5
# - Appears 268 times
#
#
# Second:
#
# - Impact Turns Aff   Neg - Michigan7 2019 BFHMRS.html5
# - Appears 264 times
#
# Third:
# - Saudi Courts Neg - Michigan7 2019 BFHR.html5
# -  Appears 214 times
#
# Fourth:
# - Allies DA - Michigan7 2019 BFHR.html5
# - Appears 195 times
#
#
# Fifth:
#
# - Nigeria Aff  - MichiganClassic 2019 BAZ.html5
# - Appears 191 times

# %%
# Look at how big the database with only the 5 subjects we chose before

df_mock = pd.read_csv('debate2019.csv')


# Get the 5 most recurrent filenames
top5_filenames = df_mock['OriginalDebateFileName'].value_counts().nlargest(5).index

# Filter the dataframe to include only the top 5 filenames
top5_df = df_mock[df_mock['OriginalDebateFileName'].isin(top5_filenames)]

# Calculate the total number of characters for the top 5 filenames
top5_chars = top5_df['Full-Document'].str.len().sum()

# Calculate the total number of characters for the entire 'Full-Document' column
total_chars = df_mock['Full-Document'].str.len().sum()

# Calculate the percentage of characters that the top 5 subjects represent
percent_top5_chars = (top5_chars / total_chars) * 100

# %%
print("New databse represents",percent_top5_chars,
      "% of the original dataset, \nwhich is small "
      "enough for fine tuning that will cost us $", percent_top5_chars*120/100)
# Out:
# New databse represents 6.105831051190056 % of the original dataset,
# which is small enough for fine tuning that will cost us $ 7.326997261428067

# %% [markdown]
# #Structure data for extraction (final chatbot version)

# %% [markdown]
# Extract data from huggingface, and reduce filesize by only keeping the subjects that have more than 150 docs.

# %%
# Install Git LFS
# !apt-get install git-lfs

# Clone the entire repository
# !git lfs clone https://huggingface.co/asaurasieu/debatebot

# Move into the repository directory

os.chdir('debatebot')

# Now you can read the file using pandas
df = pd.read_csv('debate2019.csv')
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# git-lfs is already the newest version (3.0.2-1ubuntu0.2).
# 0 upgraded, 0 newly installed, 0 to remove and 39 not upgraded.
# WARNING: 'git lfs clone' is deprecated and will not be updated
#           with new flags from 'git clone'
#
# 'git clone' has been updated in upstream Git to have comparable
# speeds to 'git lfs clone'.
# fatal: destination path 'debatebot' already exists and is not an empty directory.
# Error(s) during clone:
# git clone failed: exit status 128

# %%
df = df[['Full-Document', 'OriginalDebateFileName']]  # Keep only necessary columns
# Count the occurrence of each filename
filename_counts = df['OriginalDebateFileName'].value_counts()

# Filter filenames that appear more than 1 time and up to 80 times
filtered_filenames = filename_counts[(filename_counts > 1) & (filename_counts <= 150)].index

# Filter the dataset based on these filenames
filtered_df = df[~df['OriginalDebateFileName'].isin(filtered_filenames)]

df= filtered_df[['OriginalDebateFileName','Full-Document']]

# %%
df
# Out:
#                                   OriginalDebateFileName  \
# 255    Impact Turns Aff   Neg - Michigan7 2019 BFHMRS...
# 256    Impact Turns Aff   Neg - Michigan7 2019 BFHMRS...
# 257    Impact Turns Aff   Neg - Michigan7 2019 BFHMRS...
# 258    Impact Turns Aff   Neg - Michigan7 2019 BFHMRS...
# 259    Impact Turns Aff   Neg - Michigan7 2019 BFHMRS...
# ...                                                  ...
# 18815  Ukraine Updates Aff   Neg - Michigan7 2019 CCP...
# 18816  Ukraine Updates Aff   Neg - Michigan7 2019 CCP...
# 18817  Ukraine Updates Aff   Neg - Michigan7 2019 CCP...
# 18818  Ukraine Updates Aff   Neg - Michigan7 2019 CCP...
# 18819  Ukraine Updates Aff   Neg - Michigan7 2019 CCP...
#
#                                            Full-Document
# 255    The United States has traditionally regarded t...
# 256    Chinese or Russian non-nuclear strikes against...
# 257    The US nuclear forces modernization program ha...
# 258    Do not be alarmed by Russia's announcement of ...
# 259    “Whoever becomes the leader in this sphere wil...
# ...                                                  ...
# 18815  WASHINGTON - The United States needs more fire...
# 18816  Last week, Michael Brendan Dougherty wrote a p...
# 18817  President Obama's inaction after drawing a "re...
# 18818  The State Department says the U.S. will provid...
# 18819  As an authoritarian and centralised state, Rus...
#
# [2523 rows x 2 columns]

# %% [markdown]
# New database schema next to inital one:

# %%
from IPython.display import IFrame

# Embedding the diagram within an IFrame
display(IFrame(src='https://dbdiagram.io/e/65db79cb5cd0412774c38b95/65db7e895cd0412774c3b8b5', width=800, height=450))
# Out:
#         <iframe
#             width="560"
#             height="315"
#             src="https://dbdiagram.io/e/65db79cb5cd0412774c38b95/65db7e895cd0412774c3b8b5"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
